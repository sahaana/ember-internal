# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
import sys
import numpy as np
import pandas as pd

sys.path.append('/lfs/1/sahaana/enrichment/ember/utils')
from knn_utils import bm25_imdb_wiki_recall, compute_top_k_pd, bm25_SQuAD_sent_recall, bm25_imdb_fuzzy_recall, bm25_deepmatcher_recall


# %load_ext autoreload
# %autoreload 2

# %%
results_single[results_single['model'].apply(lambda x: 'walmart' in x)]
# Out:
#                                         indexing_left  \
# 47  [0.41625189781188965, 0.40331029891967773, 0.4...
# 48  [0.3703186511993408, 0.3631441593170166, 0.362...
# 49  [0.34470295906066895, 0.33376049995422363, 0.3...
# 72  [0.42300915718078613, 0.4301602840423584, 0.42...
# 73  [0.3323395252227783, 0.3419373035430908, 0.318...
# 74  [0.343090295791626, 0.34510064125061035, 0.336...
#
#                                        indexing_right            arch  \
# 47  [0.2635061740875244, 0.26479268074035645, 0.26...      pretrained
# 48  [0.14494729042053223, 0.14125919342041016, 0.1...  double-triplet
# 49  [0.13034820556640625, 0.1280660629272461, 0.12...  single-triplet
# 72  [0.2705512046813965, 0.2862262725830078, 0.284...      pretrained
# 73  [0.13000869750976562, 0.14252018928527832, 0.1...  double-triplet
# 74  [0.12547659873962402, 0.1287519931793213, 0.12...  single-triplet
#
#            data                                              model  \
# 47  deepmatcher  dirty_walmart_amazon_exp_data-uncased-masked-A...
# 48  deepmatcher  dirty_walmart_amazon_exp_data-uncased-masked-A...
# 49  deepmatcher  dirty_walmart_amazon_exp_data-uncased-masked-A...
# 72  deepmatcher    walmart_amazon_exp_data-uncased-masked-ALL-BM25
# 73  deepmatcher    walmart_amazon_exp_data-uncased-masked-ALL-BM25
# 74  deepmatcher    walmart_amazon_exp_data-uncased-masked-ALL-BM25
#
#     indexing_left_avg  indexing_right_avg  should_index_right  \
# 47           0.418768            0.267253                True
# 48           0.344105            0.130533                True
# 49           0.334579            0.142860                True
# 72           0.434446            0.255964                True
# 73           0.333786            0.134149                True
# 74           0.343266            0.132581                True
#
#     should_index_left  left/right  right/left
# 47              False    1.566937    0.638188
# 48              False    2.636152    0.379341
# 49              False    2.342007    0.426984
# 72              False    1.697294    0.589173
# 73              False    2.488166    0.401902
# 74              False    2.589110    0.386233

# %% [markdown]
# # single thread

# %%
results_single = pd.read_pickle('indexing_1_thread.pkl')

# %%
results_single['should_index_right'] = results_single['indexing_left_avg'] >= results_single['indexing_right_avg']

# %%
results_single['should_index_left'] = results_single['indexing_left_avg'] <= results_single['indexing_right_avg']

# %%
pd.set_option('display.max_rows', 80)
results_single
# Out:
#                                         indexing_left  \
# 0   [0.17734980583190918, 0.17404770851135254, 0.1...
# 1   [0.421649694442749, 0.401719331741333, 0.41001...
# 2   [0.36182546615600586, 0.36607909202575684, 0.3...
# 3   [0.16079926490783691, 0.15220212936401367, 0.1...
# 4   [0.16412973403930664, 0.159104585647583, 0.155...
# 5   [0.01432490348815918, 0.014107465744018555, 0....
# 6   [0.024347782135009766, 0.023081541061401367, 0...
# 7   [0.023334503173828125, 0.025254249572753906, 0...
# 8   [0.018343687057495117, 0.014872550964355469, 0...
# 9   [0.01907968521118164, 0.018255233764648438, 0....
# 10  [0.05251049995422363, 0.044953346252441406, 0....
# 11  [0.09764480590820312, 0.08139657974243164, 0.0...
# 12  [0.08134150505065918, 0.08545327186584473, 0.0...
# 13  [0.053910017013549805, 0.04536008834838867, 0....
# 14  [0.046301841735839844, 0.04865145683288574, 0....
# 15  [0.09185624122619629, 0.08269882202148438, 0.0...
# 16  [0.2095966339111328, 0.19872355461120605, 0.20...
# 17  [0.187241792678833, 0.18944025039672852, 0.186...
# 18  [0.09200358390808105, 0.09072256088256836, 0.0...
# 19  [0.09478878974914551, 0.08704352378845215, 0.0...
# 20  [0.04802560806274414, 0.0457456111907959, 0.04...
# 21  [0.10407662391662598, 0.09832358360290527, 0.1...
# 22  [0.08891940116882324, 0.1001434326171875, 0.09...
# 23  [0.05187273025512695, 0.04633736610412598, 0.0...
# 24  [0.051104068756103516, 0.0472559928894043, 0.0...
# 25  [1.3598952293395996, 1.3390467166900635, 1.342...
# 26  [2.7153773307800293, 2.9396586418151855, 2.662...
# 27  [2.721282958984375, 2.64762282371521, 2.628340...
# 28  [1.3588356971740723, 1.3163669109344482, 1.306...
# 29  [1.3753859996795654, 1.3299686908721924, 1.351...
# 30  [0.06164121627807617, 0.05273246765136719, 0.0...
# 31  [0.11974143981933594, 0.10688233375549316, 0.0...
# 32  [0.09987425804138184, 0.10435199737548828, 0.1...
# 33  [0.048926353454589844, 0.0451359748840332, 0.0...
# 34  [0.054926156997680664, 0.04961204528808594, 0....
# 35  [1.4080228805541992, 1.433852195739746, 1.4003...
# 36  [3.8528127670288086, 3.9060630798339844, 2.998...
# 37  [2.650350570678711, 2.651369333267212, 2.51367...
# 38  [1.3979301452636719, 1.3583612442016602, 1.378...
# 39  [1.328691005706787, 1.2993433475494385, 1.3075...
# 40  [2.271379232406616, 2.2552449703216553, 2.2198...
# 41  [5.190492630004883, 5.025360822677612, 5.04361...
# 42  [5.005342960357666, 5.0724098682403564, 5.0974...
# 43  [2.238619804382324, 2.1526002883911133, 2.1681...
# 44  [2.1790664196014404, 2.1025991439819336, 2.128...
# 45  [0.46152353286743164, 0.45305633544921875, 0.4...
# 46  [0.9368562698364258, 0.9183599948883057, 0.927...
# 47  [0.9192295074462891, 0.9429605007171631, 0.957...
# 48  [0.46241140365600586, 0.45299625396728516, 0.4...
# 49  [0.4527699947357178, 0.46309781074523926, 0.46...
# 50  [0.00675201416015625, 0.0032045841217041016, 0...
# 51  [0.005360603332519531, 0.004919767379760742, 0...
# 52  [0.005107402801513672, 0.0049533843994140625, ...
# 53  [0.0028336048126220703, 0.0028336048126220703,...
# 54  [0.003345966339111328, 0.0031828880310058594, ...
# 55  [0.1121525764465332, 0.09999489784240723, 0.10...
# 56  [0.2822387218475342, 0.27336740493774414, 0.28...
# 57  [0.28410840034484863, 0.29390501976013184, 0.3...
# 58  [0.1021735668182373, 0.09995746612548828, 0.09...
# 59  [0.11708736419677734, 0.101348876953125, 0.106...
# 60  [0.4797830581665039, 0.4787940979003906, 0.493...
# 61  [1.2018232345581055, 1.1927878856658936, 1.141...
# 62  [1.1864757537841797, 1.1787302494049072, 1.182...
# 63  [0.4760434627532959, 0.4761219024658203, 0.497...
# 64  [0.4760434627532959, 0.4761219024658203, 0.497...
# 65  [2.126436471939087, 2.1459434032440186, 2.1119...
# 66  [5.134614706039429, 5.091017723083496, 5.03841...
# 67  [5.009377956390381, 4.911701440811157, 5.06477...
# 68  [2.0519447326660156, 1.9968934059143066, 1.965...
# 69  [2.0598533153533936, 2.032163619995117, 2.0447...
# 70  [0.4758152961730957, 0.46034741401672363, 0.44...
# 71  [0.934985876083374, 0.9161384105682373, 0.9186...
# 72  [0.9472544193267822, 0.9027807712554932, 0.915...
# 73  [0.4487452507019043, 0.4514436721801758, 0.445...
# 74  [0.4445979595184326, 0.45959019660949707, 0.46...
#
#                                        indexing_right            arch  \
# 0   [0.1961214542388916, 0.18332958221435547, 0.18...  single-triplet
# 1   [0.3925056457519531, 0.3902125358581543, 0.405...      pretrained
# 2   [0.36196017265319824, 0.3635697364807129, 0.39...      pretrained
# 3   [0.16853547096252441, 0.17053794860839844, 0.1...  double-triplet
# 4   [0.1663227081298828, 0.16763544082641602, 0.16...  single-triplet
# 5   [0.01467585563659668, 0.013896703720092773, 0....  single-triplet
# 6   [0.03154158592224121, 0.024834632873535156, 0....      pretrained
# 7   [0.025003671646118164, 0.027796030044555664, 0...      pretrained
# 8   [0.014444589614868164, 0.01477360725402832, 0....  double-triplet
# 9   [0.01834702491760254, 0.018728017807006836, 0....  single-triplet
# 10  [0.03281402587890625, 0.03235602378845215, 0.0...  single-triplet
# 11  [0.07592535018920898, 0.08031773567199707, 0.0...      pretrained
# 12  [0.07325983047485352, 0.07381939888000488, 0.0...      pretrained
# 13  [0.03193306922912598, 0.0326695442199707, 0.03...  double-triplet
# 14  [0.03163743019104004, 0.0312802791595459, 0.02...  single-triplet
# 15  [0.10362720489501953, 0.09589004516601562, 0.0...  single-triplet
# 16  [0.21652746200561523, 0.22995734214782715, 0.2...      pretrained
# 17  [0.19636034965515137, 0.19085359573364258, 0.1...      pretrained
# 18  [0.09543466567993164, 0.08897089958190918, 0.0...  double-triplet
# 19  [0.10929393768310547, 0.1066431999206543, 0.09...  single-triplet
# 20  [0.05141949653625488, 0.04706597328186035, 0.0...  single-triplet
# 21  [0.09986639022827148, 0.10224151611328125, 0.1...      pretrained
# 22  [0.09637451171875, 0.09587907791137695, 0.0972...      pretrained
# 23  [0.049246788024902344, 0.0447993278503418, 0.0...  double-triplet
# 24  [0.051189422607421875, 0.04924416542053223, 0....  single-triplet
# 25  [0.7014009952545166, 0.6991596221923828, 0.721...  single-triplet
# 26  [2.1693553924560547, 2.1432063579559326, 2.110...      pretrained
# 27  [2.119964361190796, 2.0056519508361816, 2.1197...      pretrained
# 28  [0.7678523063659668, 0.7031698226928711, 0.731...  double-triplet
# 29  [0.6889841556549072, 0.6484625339508057, 0.763...  single-triplet
# 30  [0.05340695381164551, 0.051496267318725586, 0....  single-triplet
# 31  [0.10680031776428223, 0.10388612747192383, 0.1...      pretrained
# 32  [0.11820197105407715, 0.1046142578125, 0.11131...      pretrained
# 33  [0.06688618659973145, 0.051975250244140625, 0....  double-triplet
# 34  [0.062383174896240234, 0.07309556007385254, 0....  single-triplet
# 35  [0.7284896373748779, 0.7115592956542969, 0.721...  single-triplet
# 36  [2.170715570449829, 2.1617465019226074, 2.1470...      pretrained
# 37  [2.1646628379821777, 2.1823959350585938, 2.161...      pretrained
# 38  [0.7152516841888428, 0.6929292678833008, 0.700...  double-triplet
# 39  [0.7312676906585693, 0.7116928100585938, 0.680...  single-triplet
# 40  [1.556901216506958, 1.5227415561676025, 1.5333...  single-triplet
# 41  [4.409409284591675, 4.471446514129639, 4.56719...      pretrained
# 42  [4.527221202850342, 4.504037618637085, 4.58961...      pretrained
# 43  [1.503026008605957, 1.5303175449371338, 1.4962...  double-triplet
# 44  [1.544064998626709, 1.5645060539245605, 1.5294...  single-triplet
# 45  [0.2679157257080078, 0.2589445114135742, 0.253...  single-triplet
# 46  [0.7219305038452148, 0.7382068634033203, 0.734...      pretrained
# 47  [0.720839262008667, 0.6768763065338135, 0.6654...      pretrained
# 48  [0.23875188827514648, 0.25476646423339844, 0.2...  double-triplet
# 49  [0.25346946716308594, 0.2509474754333496, 0.25...  single-triplet
# 50  [0.00426936149597168, 0.004107475280761719, 0....  single-triplet
# 51  [0.006403207778930664, 0.006377696990966797, 0...      pretrained
# 52  [0.00574493408203125, 0.0056836605072021484, 0...      pretrained
# 53  [0.004882335662841797, 0.004874229431152344, 0...  double-triplet
# 54  [0.0040056705474853516, 0.003930807113647461, ...  single-triplet
# 55  [0.18041372299194336, 0.1769106388092041, 0.17...  single-triplet
# 56  [0.3741576671600342, 0.3824162483215332, 0.339...      pretrained
# 57  [0.34198784828186035, 0.32410264015197754, 0.3...      pretrained
# 58  [0.18680763244628906, 0.17789554595947266, 0.1...  double-triplet
# 59  [0.17009329795837402, 0.17507028579711914, 0.1...  single-triplet
# 60  [0.47744274139404297, 0.48030710220336914, 0.4...  single-triplet
# 61  [1.159804344177246, 1.152440071105957, 1.15639...      pretrained
# 62  [1.1793286800384521, 1.189349889755249, 1.1937...      pretrained
# 63  [0.47411155700683594, 0.48607468605041504, 0.4...  double-triplet
# 64  [0.47411155700683594, 0.48607468605041504, 0.4...  single-triplet
# 65  [1.5647330284118652, 1.5829308032989502, 1.570...  single-triplet
# 66  [4.722642660140991, 4.558377742767334, 4.60928...      pretrained
# 67  [4.57377028465271, 4.453278541564941, 4.560304...      pretrained
# 68  [1.4730713367462158, 1.4900074005126953, 1.581...  double-triplet
# 69  [1.5059432983398438, 1.5667614936828613, 1.553...  single-triplet
# 70  [0.24671411514282227, 0.26269078254699707, 0.2...  single-triplet
# 71  [0.7360970973968506, 0.7529089450836182, 0.746...      pretrained
# 72  [0.7628567218780518, 0.789048433303833, 0.7447...      pretrained
# 73  [0.241286039352417, 0.24978899955749512, 0.252...  double-triplet
# 74  [0.2560863494873047, 0.2668039798736572, 0.282...  single-triplet
#
#                data                                              model  \
# 0        SQuAD_sent                            distilbert-base-uncased
# 1        SQuAD_sent                            distilbert-base-uncased
# 2        SQuAD_sent  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 3        SQuAD_sent  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 4        SQuAD_sent  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 5       deepmatcher                            distilbert-base-uncased
# 6       deepmatcher                            distilbert-base-uncased
# 7       deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 8       deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 9       deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 10      deepmatcher                            distilbert-base-uncased
# 11      deepmatcher                            distilbert-base-uncased
# 12      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 13      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 14      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 15      deepmatcher                            distilbert-base-uncased
# 16      deepmatcher                            distilbert-base-uncased
# 17      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 18      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 19      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 20      deepmatcher                            distilbert-base-uncased
# 21      deepmatcher                            distilbert-base-uncased
# 22      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 23      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 24      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 25      deepmatcher                            distilbert-base-uncased
# 26      deepmatcher                            distilbert-base-uncased
# 27      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 28      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 29      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 30      deepmatcher                            distilbert-base-uncased
# 31      deepmatcher                            distilbert-base-uncased
# 32      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 33      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 34      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 35      deepmatcher                            distilbert-base-uncased
# 36      deepmatcher                            distilbert-base-uncased
# 37      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 38      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 39      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 40      deepmatcher                            distilbert-base-uncased
# 41      deepmatcher                            distilbert-base-uncased
# 42      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 43      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 44      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 45      deepmatcher                            distilbert-base-uncased
# 46      deepmatcher                            distilbert-base-uncased
# 47      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 48      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 49      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 50      deepmatcher                            distilbert-base-uncased
# 51      deepmatcher                            distilbert-base-uncased
# 52      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 53      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 54      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 55  hard_imdb_fuzzy                            distilbert-base-uncased
# 56  hard_imdb_fuzzy                            distilbert-base-uncased
# 57  hard_imdb_fuzzy  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 58  hard_imdb_fuzzy  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 59  hard_imdb_fuzzy  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 60        imdb_wiki                            distilbert-base-uncased
# 61        imdb_wiki                            distilbert-base-uncased
# 62        imdb_wiki  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 63        imdb_wiki  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 64        imdb_wiki  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 65      deepmatcher                            distilbert-base-uncased
# 66      deepmatcher                            distilbert-base-uncased
# 67      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 68      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 69      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 70      deepmatcher                            distilbert-base-uncased
# 71      deepmatcher                            distilbert-base-uncased
# 72      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 73      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
# 74      deepmatcher  /lfs/1/sahaana/enrichment//ember/pretraining/m...
#
#     indexing_left_avg  indexing_right_avg  should_index_right  \
# 0            0.166793            0.181986               False
# 1            0.401409            0.398311                True
# 2            0.359940            0.388104               False
# 3            0.159077            0.167180               False
# 4            0.155377            0.163280               False
# 5            0.014198            0.014267               False
# 6            0.024347            0.026074               False
# 7            0.024262            0.026346               False
# 8            0.014511            0.014694               False
# 9            0.014873            0.014913               False
# 10           0.046511            0.032195                True
# 11           0.087116            0.081498                True
# 12           0.082302            0.071929                True
# 13           0.046306            0.032651                True
# 14           0.046390            0.032264                True
# 15           0.087184            0.097539               False
# 16           0.206585            0.208826               False
# 17           0.191739            0.202724               False
# 18           0.081301            0.095521               False
# 19           0.089156            0.099634               False
# 20           0.046788            0.049950               False
# 21           0.103307            0.111860               False
# 22           0.097111            0.098274               False
# 23           0.048792            0.051101               False
# 24           0.046582            0.050861               False
# 25           1.317216            0.704802                True
# 26           2.725014            2.105287                True
# 27           2.628000            2.112155                True
# 28           1.342835            0.722396                True
# 29           1.351616            0.741852                True
# 30           0.048356            0.053528               False
# 31           0.104540            0.107333               False
# 32           0.102009            0.109992               False
# 33           0.048262            0.051956               False
# 34           0.049317            0.055423               False
# 35           1.377375            0.727358                True
# 36           2.854635            2.144395                True
# 37           2.633546            2.198109                True
# 38           1.372050            0.689581                True
# 39           1.337202            0.692460                True
# 40           2.134708            1.533272                True
# 41           4.996243            4.569979                True
# 42           5.008700            4.532185                True
# 43           2.106526            1.491505                True
# 44           2.049738            1.533391                True
# 45           0.450421            0.254200                True
# 46           0.911717            0.739021                True
# 47           0.891844            0.707419                True
# 48           0.452580            0.239656                True
# 49           0.462709            0.249276                True
# 50           0.003425            0.004336               False
# 51           0.005008            0.006387               False
# 52           0.004941            0.006023               False
# 53           0.002895            0.004836               False
# 54           0.003435            0.003981               False
# 55           0.103020            0.176895               False
# 56           0.288202            0.342907               False
# 57           0.291214            0.330187               False
# 58           0.101004            0.176640               False
# 59           0.102840            0.176171               False
# 60           0.472501            0.481837               False
# 61           1.162843            1.142343                True
# 62           1.185327            1.186678               False
# 63           0.483284            0.478488                True
# 64           0.483284            0.478488                True
# 65           2.132699            1.543592                True
# 66           5.042033            4.636464                True
# 67           4.985436            4.533501                True
# 68           2.054755            1.499086                True
# 69           1.972822            1.559389                True
# 70           0.463726            0.250332                True
# 71           0.916872            0.743071                True
# 72           0.911836            0.753119                True
# 73           0.450001            0.250612                True
# 74           0.453814            0.249384                True
#
#     should_index_left
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True
# 10              False
# 11              False
# 12              False
# 13              False
# 14              False
# 15               True
# 16               True
# 17               True
# 18               True
# 19               True
# 20               True
# 21               True
# 22               True
# 23               True
# 24               True
# 25              False
# 26              False
# 27              False
# 28              False
# 29              False
# 30               True
# 31               True
# 32               True
# 33               True
# 34               True
# 35              False
# 36              False
# 37              False
# 38              False
# 39              False
# 40              False
# 41              False
# 42              False
# 43              False
# 44              False
# 45              False
# 46              False
# 47              False
# 48              False
# 49              False
# 50               True
# 51               True
# 52               True
# 53               True
# 54               True
# 55               True
# 56               True
# 57               True
# 58               True
# 59               True
# 60               True
# 61              False
# 62               True
# 63              False
# 64              False
# 65              False
# 66              False
# 67              False
# 68              False
# 69              False
# 70              False
# 71              False
# 72              False
# 73              False
# 74              False

# %% [markdown]
# # Multi-thread

# %% [raw]
# single trial marco values
# Indexing Left:  237.20603561401367
# Indexing Right:  116.64833569526672
#
#
# MSMARCO
# double-triplet   /lfs/1/sahaana/enrichment//ember/pretraining/models/MARCO-uncased-masked-ALL-BM25
# /lfs/1/sahaana/enrichment/ember/embedding/configs//MSMARCO-uncased-masked-ALL-BM25-double-triplet-397768673-1.json
# Indexing Left:  257.33129382133484
# Indexing Right:  128.70932483673096
#
#
# MSMARCO
# single-triplet   /lfs/1/sahaana/enrichment//ember/pretraining/models/MARCO-uncased-masked-ALL-BM25
# /lfs/1/sahaana/enrichment/ember/embedding/configs//MSMARCO-uncased-masked-ALL-BM25-single-triplet-397768673-1.json
# Indexing Left:  284.1396803855896
# Indexing Right:  118.11620783805847

# %%
marco_values = [284.1396803855896/118.11620783805847, 257.33129382133484/128.70932483673096, 237.20603561401367/116.64833569526672]

# %%
marco_values

# %%
results_single = pd.read_pickle('indexing_56_threads.pkl')

# %%
results_single['should_index_right'] = results_single['indexing_left_avg'] >= results_single['indexing_right_avg']

# %%
results_single['should_index_left'] = results_single['indexing_left_avg'] <= results_single['indexing_right_avg']
results_single['model'] = results_single['model'].apply(lambda x: x.split('/')[-1])

# %%
results_single['left/right'] = results_single['indexing_left_avg']/results_single['indexing_right_avg']
results_single['right/left'] = results_single['indexing_right_avg']/results_single['indexing_left_avg']

# %%
np.mean(results_single[['left/right','right/left']].max(axis=1))
# Out:
# 1.5756945369321038

# %%
results_single[['left/right','right/left']].max(axis=1)
# Out:
# 0     1.056781
# 1     1.113275
# 2     1.010303
# 3     1.107861
# 4     1.079995
# 5     1.005189
# 6     1.154624
# 7     1.130226
# 8     1.019093
# 9     1.021347
# 10    1.566942
# 11    1.000168
# 12    1.290039
# 13    1.473544
# 14    1.556325
# 15    1.193415
# 16    1.215964
# 17    1.352811
# 18    1.020333
# 19    1.287862
# 20    1.099910
# 21    1.093044
# 22    1.012607
# 23    1.096473
# 24    1.021328
# 25    2.695864
# 26    1.729461
# 27    2.046457
# 28    2.822252
# 29    2.807072
# 30    1.159958
# 31    1.018208
# 32    1.075495
# 33    1.112240
# 34    1.077647
# 35    2.747832
# 36    1.875373
# 37    1.698276
# 38    2.994010
# 39    2.547212
# 40    1.827738
# 41    1.498543
# 42    1.426711
# 43    1.723659
# 44    1.764607
# 45    2.568852
# 46    1.642632
# 47    1.566937
# 48    2.636152
# 49    2.342007
# 50    1.164997
# 51    1.236119
# 52    1.128966
# 53    1.932001
# 54    1.171424
# 55    2.365341
# 56    1.342773
# 57    1.403874
# 58    2.109441
# 59    2.486711
# 60    1.016776
# 61    1.036463
# 62    1.026959
# 63    1.000248
# 64    1.000248
# 65    1.996622
# 66    1.345060
# 67    1.368651
# 68    1.843714
# 69    1.751040
# 70    2.612708
# 71    1.677729
# 72    1.697294
# 73    2.488166
# 74    2.589110
# dtype: float64

# %%
pd.set_option('display.max_rows', 80)
results_single[((results_single['arch']=='single-triplet') & (results_single['model'] !='distilbert-base-uncased'))]
# Out:
#                                         indexing_left  \
# 4   [0.09956073760986328, 0.09800505638122559, 0.1...
# 9   [0.014408349990844727, 0.012155532836914062, 0...
# 14  [0.03751873970031738, 0.03639841079711914, 0.0...
# 19  [0.061959266662597656, 0.05873894691467285, 0....
# 24  [0.03942394256591797, 0.03949761390686035, 0.0...
# 29  [1.061077356338501, 1.0461342334747314, 0.9922...
# 34  [0.03552865982055664, 0.03468751907348633, 0.0...
# 39  [0.9556877613067627, 1.0709960460662842, 1.051...
# 44  [1.4334759712219238, 1.4243135452270508, 1.426...
# 49  [0.34470295906066895, 0.33376049995422363, 0.3...
# 54  [0.0033245086669921875, 0.0032525062561035156,...
# 59  [0.061400413513183594, 0.05693411827087402, 0....
# 64  [0.31818366050720215, 0.27179574966430664, 0.2...
# 69  [1.2259628772735596, 1.2021808624267578, 1.216...
# 74  [0.343090295791626, 0.34510064125061035, 0.336...
#
#                                        indexing_right            arch  \
# 4   [0.1287224292755127, 0.12823796272277832, 0.12...  single-triplet
# 9   [0.012151241302490234, 0.01221013069152832, 0....  single-triplet
# 14  [0.023518085479736328, 0.023508310317993164, 0...  single-triplet
# 19  [0.07077622413635254, 0.0745534896850586, 0.08...  single-triplet
# 24  [0.037290096282958984, 0.037940263748168945, 0...  single-triplet
# 29  [0.35051584243774414, 0.35817527770996094, 0.3...  single-triplet
# 34  [0.04224109649658203, 0.0421905517578125, 0.04...  single-triplet
# 39  [0.36053466796875, 0.36368322372436523, 0.4010...  single-triplet
# 44  [0.6917638778686523, 0.7019999027252197, 0.713...  single-triplet
# 49  [0.13034820556640625, 0.1280660629272461, 0.12...  single-triplet
# 54  [0.0037581920623779297, 0.003753662109375, 0.0...  single-triplet
# 59  [0.15239334106445312, 0.15079021453857422, 0.1...  single-triplet
# 64  [0.2626612186431885, 0.2648634910583496, 0.264...  single-triplet
# 69  [0.7544820308685303, 0.7635130882263184, 0.669...  single-triplet
# 74  [0.12547659873962402, 0.1287519931793213, 0.12...  single-triplet
#
#                data                                              model  \
# 4        SQuAD_sent                 SQuAD_sent-uncased-masked-ALL-BM25
# 9       deepmatcher           abt_buy_exp_data-uncased-masked-ALL-BM25
# 14      deepmatcher     amazon_google_exp_data-uncased-masked-ALL-BM25
# 19      deepmatcher              beer_exp_data-uncased-masked-ALL-BM25
# 24      deepmatcher          dblp_acm_exp_data-uncased-masked-ALL-BM25
# 29      deepmatcher      dblp_scholar_exp_data-uncased-masked-ALL-BM25
# 34      deepmatcher    dirty_dblp_acm_exp_data-uncased-masked-ALL-BM25
# 39      deepmatcher  dirty_dblp_scholar_exp_data-uncased-masked-ALL...
# 44      deepmatcher  dirty_itunes_amazon_exp_data-uncased-masked-AL...
# 49      deepmatcher  dirty_walmart_amazon_exp_data-uncased-masked-A...
# 54      deepmatcher      fodors_zagat_exp_data-uncased-masked-ALL-BM25
# 59  hard_imdb_fuzzy            hard_imdb_fuzzy-uncased-masked-ALL-BM25
# 64        imdb_wiki                  imdb_wiki-uncased-masked-ALL-BM25
# 69      deepmatcher     itunes_amazon_exp_data-uncased-masked-ALL-BM25
# 74      deepmatcher    walmart_amazon_exp_data-uncased-masked-ALL-BM25
#
#     indexing_left_avg  indexing_right_avg  should_index_right  \
# 4            0.107974            0.116612               False
# 9            0.012490            0.012229                True
# 14           0.037131            0.023858                True
# 19           0.056979            0.073381               False
# 24           0.037373            0.038170               False
# 29           0.985758            0.351169                True
# 34           0.038185            0.041150               False
# 39           0.987824            0.387806                True
# 44           1.324084            0.750356                True
# 49           0.334579            0.142860                True
# 54           0.003250            0.003807               False
# 59           0.063138            0.157006               False
# 64           0.303022            0.302947                True
# 69           1.216626            0.694802                True
# 74           0.343266            0.132581                True
#
#     should_index_left  left/right  right/left
# 4                True    0.925930    1.079995
# 9               False    1.021347    0.979099
# 14              False    1.556325    0.642539
# 19               True    0.776481    1.287862
# 24               True    0.979118    1.021328
# 29              False    2.807072    0.356243
# 34               True    0.927948    1.077647
# 39              False    2.547212    0.392586
# 44              False    1.764607    0.566698
# 49              False    2.342007    0.426984
# 54               True    0.853662    1.171424
# 59               True    0.402138    2.486711
# 64              False    1.000248    0.999752
# 69              False    1.751040    0.571089
# 74              False    2.589110    0.386233

# %%
# company, marco, small_imdb_fuzzy
# Out:
# 0                               distilbert-base-uncased
# 1                               distilbert-base-uncased
# 2                    SQuAD_sent-uncased-masked-ALL-BM25
# 3                    SQuAD_sent-uncased-masked-ALL-BM25
# 4                    SQuAD_sent-uncased-masked-ALL-BM25
# 5                               distilbert-base-uncased
# 6                               distilbert-base-uncased
# 7              abt_buy_exp_data-uncased-masked-ALL-BM25
# 8              abt_buy_exp_data-uncased-masked-ALL-BM25
# 9              abt_buy_exp_data-uncased-masked-ALL-BM25
# 10                              distilbert-base-uncased
# 11                              distilbert-base-uncased
# 12       amazon_google_exp_data-uncased-masked-ALL-BM25
# 13       amazon_google_exp_data-uncased-masked-ALL-BM25
# 14       amazon_google_exp_data-uncased-masked-ALL-BM25
# 15                              distilbert-base-uncased
# 16                              distilbert-base-uncased
# 17                beer_exp_data-uncased-masked-ALL-BM25
# 18                beer_exp_data-uncased-masked-ALL-BM25
# 19                beer_exp_data-uncased-masked-ALL-BM25
# 20                              distilbert-base-uncased
# 21                              distilbert-base-uncased
# 22            dblp_acm_exp_data-uncased-masked-ALL-BM25
# 23            dblp_acm_exp_data-uncased-masked-ALL-BM25
# 24            dblp_acm_exp_data-uncased-masked-ALL-BM25
# 25                              distilbert-base-uncased
# 26                              distilbert-base-uncased
# 27        dblp_scholar_exp_data-uncased-masked-ALL-BM25
# 28        dblp_scholar_exp_data-uncased-masked-ALL-BM25
# 29        dblp_scholar_exp_data-uncased-masked-ALL-BM25
# 30                              distilbert-base-uncased
# 31                              distilbert-base-uncased
# 32      dirty_dblp_acm_exp_data-uncased-masked-ALL-BM25
# 33      dirty_dblp_acm_exp_data-uncased-masked-ALL-BM25
# 34      dirty_dblp_acm_exp_data-uncased-masked-ALL-BM25
# 35                              distilbert-base-uncased
# 36                              distilbert-base-uncased
# 37    dirty_dblp_scholar_exp_data-uncased-masked-ALL...
# 38    dirty_dblp_scholar_exp_data-uncased-masked-ALL...
# 39    dirty_dblp_scholar_exp_data-uncased-masked-ALL...
# 40                              distilbert-base-uncased
# 41                              distilbert-base-uncased
# 42    dirty_itunes_amazon_exp_data-uncased-masked-AL...
# 43    dirty_itunes_amazon_exp_data-uncased-masked-AL...
# 44    dirty_itunes_amazon_exp_data-uncased-masked-AL...
# 45                              distilbert-base-uncased
# 46                              distilbert-base-uncased
# 47    dirty_walmart_amazon_exp_data-uncased-masked-A...
# 48    dirty_walmart_amazon_exp_data-uncased-masked-A...
# 49    dirty_walmart_amazon_exp_data-uncased-masked-A...
# 50                              distilbert-base-uncased
# 51                              distilbert-base-uncased
# 52        fodors_zagat_exp_data-uncased-masked-ALL-BM25
# 53        fodors_zagat_exp_data-uncased-masked-ALL-BM25
# 54        fodors_zagat_exp_data-uncased-masked-ALL-BM25
# 55                              distilbert-base-uncased
# 56                              distilbert-base-uncased
# 57              hard_imdb_fuzzy-uncased-masked-ALL-BM25
# 58              hard_imdb_fuzzy-uncased-masked-ALL-BM25
# 59              hard_imdb_fuzzy-uncased-masked-ALL-BM25
# 60                              distilbert-base-uncased
# 61                              distilbert-base-uncased
# 62                    imdb_wiki-uncased-masked-ALL-BM25
# 63                    imdb_wiki-uncased-masked-ALL-BM25
# 64                    imdb_wiki-uncased-masked-ALL-BM25
# 65                              distilbert-base-uncased
# 66                              distilbert-base-uncased
# 67       itunes_amazon_exp_data-uncased-masked-ALL-BM25
# 68       itunes_amazon_exp_data-uncased-masked-ALL-BM25
# 69       itunes_amazon_exp_data-uncased-masked-ALL-BM25
# 70                              distilbert-base-uncased
# 71                              distilbert-base-uncased
# 72      walmart_amazon_exp_data-uncased-masked-ALL-BM25
# 73      walmart_amazon_exp_data-uncased-masked-ALL-BM25
# 74      walmart_amazon_exp_data-uncased-masked-ALL-BM25
# Name: model, dtype: object

# %% [markdown]
# # Multi-thread (for sim join end to end comparison)

# %%
marco = 118.11620783805847
company = 1.8847980976104737

# %%
results_single = pd.read_pickle('indexing_56_threads.pkl')

# %%
results_single['should_index_right'] = results_single['indexing_left_avg'] >= results_single['indexing_right_avg']

# %%
results_single['should_index_left'] = results_single['indexing_left_avg'] <= results_single['indexing_right_avg']
results_single['model'] = results_single['model'].apply(lambda x: x.split('/')[-1])

# %%
filtered = results_single[results_single['model'].apply(lambda x: 'uncased-masked-ALL' in x) & results_single['arch'].apply(lambda x: 'single-triplet' in x)]
filtered = filtered[['model','indexing_left_avg','indexing_right_avg']]
filtered['model'] = filtered['model'].apply(lambda x: x.split('-')[0])

# %%
filtered['min'] = filtered.apply(lambda x: min(x.indexing_left_avg, x.indexing_right_avg), axis=1)
filtered = filtered.append({'model':'marco','min':marco}, ignore_index=True)
filtered = filtered.append({'model':'company','min':company}, ignore_index=True)

# %%
filtered
# Out:
#                             model  indexing_left_avg  indexing_right_avg  \
# 0                      SQuAD_sent           0.107974            0.116612
# 1                abt_buy_exp_data           0.012490            0.012229
# 2          amazon_google_exp_data           0.037131            0.023858
# 3                   beer_exp_data           0.056979            0.073381
# 4               dblp_acm_exp_data           0.037373            0.038170
# 5           dblp_scholar_exp_data           0.985758            0.351169
# 6         dirty_dblp_acm_exp_data           0.038185            0.041150
# 7     dirty_dblp_scholar_exp_data           0.987824            0.387806
# 8    dirty_itunes_amazon_exp_data           1.324084            0.750356
# 9   dirty_walmart_amazon_exp_data           0.334579            0.142860
# 10          fodors_zagat_exp_data           0.003250            0.003807
# 11                hard_imdb_fuzzy           0.063138            0.157006
# 12                      imdb_wiki           0.303022            0.302947
# 13         itunes_amazon_exp_data           1.216626            0.694802
# 14        walmart_amazon_exp_data           0.343266            0.132581
# 15                          marco                NaN                 NaN
# 16                        company                NaN                 NaN
#
#            min
# 0     0.107974
# 1     0.012229
# 2     0.023858
# 3     0.056979
# 4     0.037373
# 5     0.351169
# 6     0.038185
# 7     0.387806
# 8     0.750356
# 9     0.142860
# 10    0.003250
# 11    0.063138
# 12    0.302947
# 13    0.694802
# 14    0.132581
# 15  118.116208
# 16    1.884798

# %%
np.average(filtered[filtered.model != 'marco']['min'])
# Out:
# 0.3118941223621368

# %%
np.average(filtered['min'])
# Out:
# 7.241559635050156

# %%
list(filtered.model)
# Out:
# ['SQuAD_sent',
#  'abt_buy_exp_data',
#  'amazon_google_exp_data',
#  'beer_exp_data',
#  'dblp_acm_exp_data',
#  'dblp_scholar_exp_data',
#  'dirty_dblp_acm_exp_data',
#  'dirty_dblp_scholar_exp_data',
#  'dirty_itunes_amazon_exp_data',
#  'dirty_walmart_amazon_exp_data',
#  'fodors_zagat_exp_data',
#  'hard_imdb_fuzzy',
#  'imdb_wiki',
#  'itunes_amazon_exp_data',
#  'walmart_amazon_exp_data',
#  'marco',
#  'company']

# %%
types = ['key_edit', 'key_jac_ws', "key_jac_2g", "mer_jac_ws", "mer_jac_2g"]
simjoin = pd.read_pickle('simjoin-iters_5.pkl')
simjoin
# Out:
#           data        type                                            results  \
# 0   main_fuzzy    key_edit  [4.485604524612427, 2.8411519527435303, 3.4615...
# 1   main_fuzzy  key_jac_ws  [0.6551518440246582, 0.46874403953552246, 0.56...
# 2   main_fuzzy  key_jac_2g  [1.1006782054901123, 1.2680299282073975, 1.123...
# 3   main_fuzzy  mer_jac_ws  [5.829527854919434, 6.058440208435059, 6.31795...
# 4   main_fuzzy  mer_jac_2g  [12.2832670211792, 12.011268615722656, 11.8850...
# ..         ...         ...                                                ...
# 80       marco    key_edit  [4421.601225137711, 4433.547817230225, 4462.33...
# 81       marco  key_jac_ws  [4803.888113260269, 4910.017649412155, 4966.68...
# 82       marco  key_jac_2g  [4586.826099872589, 4848.72921538353, 4790.750...
# 83       marco  mer_jac_ws  [4803.888113260269, 4910.017649412155, 4966.68...
# 84       marco  mer_jac_2g  [4586.826099872589, 4848.72921538353, 4790.750...
#
#             avg
# 0      3.313628
# 1      0.579899
# 2      1.148822
# 3      6.044274
# 4     12.285134
# ..          ...
# 80  4452.181175
# 81  4784.071830
# 82  4637.044397
# 83  4784.071830
# 84  4637.044397
#
# [85 rows x 4 columns]

# %%
for i in types:
    rt = simjoin[simjoin['type']==i]
    print(i, np.average(rt['avg']))
    print(rt)
    print()
# Out:
# key_edit 1418.0993946131537
#                                     data      type  \
# 0                             main_fuzzy  key_edit
# 5                              imdb_wiki  key_edit
# 10                                 squad  key_edit
# 15               joined_abt_buy_exp_data  key_edit
# 20         joined_amazon_google_exp_data  key_edit
# 25                  joined_beer_exp_data  key_edit
# 30              joined_dblp_acm_exp_data  key_edit
# 35          joined_dblp_scholar_exp_data  key_edit
# 40        joined_dirty_dblp_acm_exp_data  key_edit
# 45    joined_dirty_dblp_scholar_exp_data  key_edit
# 50   joined_dirty_itunes_amazon_exp_data  key_edit
# 55  joined_dirty_walmart_amazon_exp_data  key_edit
# 60          joined_fodors_zagat_exp_data  key_edit
# 65         joined_itunes_amazon_exp_data  key_edit
# 70        joined_walmart_amazon_exp_data  key_edit
# 75               joined_company_exp_data  key_edit
# 80                                 marco  key_edit
#
#                                               results           avg
# 0   [4.485604524612427, 2.8411519527435303, 3.4615...      3.313628
# 5   [15.502436399459839, 15.810624361038208, 15.53...     15.829078
# 10  [4.580712080001831, 4.568799734115601, 4.78547...      4.626091
# 15  [0.5552177429199219, 0.5217618942260742, 0.547...      0.533922
# 20  [0.9294345378875732, 1.0166561603546143, 1.052...      0.982627
# 25  [2.498084545135498, 2.5700576305389404, 2.3671...      2.517732
# 30  [2.2215828895568848, 2.118825912475586, 2.2097...      2.145791
# 35  [44.14492607116699, 43.17272758483887, 43.3564...     43.527170
# 40  [3.004638910293579, 2.994880437850952, 2.81175...      2.922359
# 45  [57.073222160339355, 57.42339038848877, 57.086...     56.997027
# 50  [117.8586220741272, 120.24718809127808, 120.09...    119.038240
# 55  [21.000849723815918, 21.232730388641357, 21.57...     21.347193
# 60  [0.1300652027130127, 0.12146258354187012, 0.12...      0.133091
# 65  [47.77400207519531, 48.65796899795532, 49.6329...     48.388612
# 70  [14.237792730331421, 13.295336723327637, 13.88...     14.009949
# 75  [19468.926852703094, 19444.28399515152, 19337....  19319.196024
# 80  [4421.601225137711, 4433.547817230225, 4462.33...   4452.181175
#
# key_jac_ws 301.34786949157717
#                                     data        type  \
# 1                             main_fuzzy  key_jac_ws
# 6                              imdb_wiki  key_jac_ws
# 11                                 squad  key_jac_ws
# 16               joined_abt_buy_exp_data  key_jac_ws
# 21         joined_amazon_google_exp_data  key_jac_ws
# 26                  joined_beer_exp_data  key_jac_ws
# 31              joined_dblp_acm_exp_data  key_jac_ws
# 36          joined_dblp_scholar_exp_data  key_jac_ws
# 41        joined_dirty_dblp_acm_exp_data  key_jac_ws
# 46    joined_dirty_dblp_scholar_exp_data  key_jac_ws
# 51   joined_dirty_itunes_amazon_exp_data  key_jac_ws
# 56  joined_dirty_walmart_amazon_exp_data  key_jac_ws
# 61          joined_fodors_zagat_exp_data  key_jac_ws
# 66         joined_itunes_amazon_exp_data  key_jac_ws
# 71        joined_walmart_amazon_exp_data  key_jac_ws
# 76               joined_company_exp_data  key_jac_ws
# 81                                 marco  key_jac_ws
#
#                                               results          avg
# 1   [0.6551518440246582, 0.46874403953552246, 0.56...     0.579899
# 6   [1.4831795692443848, 2.4287590980529785, 1.523...     1.851097
# 11  [0.6747803688049316, 0.7463357448577881, 0.744...     0.715607
# 16  [0.11580967903137207, 0.14850139617919922, 0.1...     0.129241
# 21  [0.14607858657836914, 0.17749762535095215, 0.1...     0.173584
# 26  [0.6114592552185059, 0.7516725063323975, 0.666...     0.695143
# 31  [0.31427955627441406, 0.2908785343170166, 0.27...     0.298967
# 36  [2.5804028511047363, 2.5229434967041016, 2.453...     2.503240
# 41  [0.32469654083251953, 0.34932851791381836, 0.7...     0.432464
# 46  [2.305058717727661, 2.1725497245788574, 2.2429...     2.205172
# 51  [14.936867713928223, 15.27736210823059, 15.522...    15.299003
# 56  [0.9500739574432373, 0.4640202522277832, 0.410...     0.824385
# 61  [0.10409903526306152, 0.11127614974975586, 0.1...     0.104978
# 66  [11.45547866821289, 11.111757040023804, 11.723...    11.419183
# 71  [0.3693861961364746, 0.40796923637390137, 0.44...     0.408158
# 76  [277.45003938674927, 336.8758387565613, 327.14...   301.201831
# 81  [4803.888113260269, 4910.017649412155, 4966.68...  4784.071830
#
# key_jac_2g 374.10771257737105
#                                     data        type  \
# 2                             main_fuzzy  key_jac_2g
# 7                              imdb_wiki  key_jac_2g
# 12                                 squad  key_jac_2g
# 17               joined_abt_buy_exp_data  key_jac_2g
# 22         joined_amazon_google_exp_data  key_jac_2g
# 27                  joined_beer_exp_data  key_jac_2g
# 32              joined_dblp_acm_exp_data  key_jac_2g
# 37          joined_dblp_scholar_exp_data  key_jac_2g
# 42        joined_dirty_dblp_acm_exp_data  key_jac_2g
# 47    joined_dirty_dblp_scholar_exp_data  key_jac_2g
# 52   joined_dirty_itunes_amazon_exp_data  key_jac_2g
# 57  joined_dirty_walmart_amazon_exp_data  key_jac_2g
# 62          joined_fodors_zagat_exp_data  key_jac_2g
# 67         joined_itunes_amazon_exp_data  key_jac_2g
# 72        joined_walmart_amazon_exp_data  key_jac_2g
# 77               joined_company_exp_data  key_jac_2g
# 82                                 marco  key_jac_2g
#
#                                               results          avg
# 2   [1.1006782054901123, 1.2680299282073975, 1.123...     1.148822
# 7   [3.2183263301849365, 3.2381386756896973, 3.193...     3.134274
# 12  [7.389421701431274, 7.552238464355469, 7.46662...     7.475550
# 17  [0.38313794136047363, 0.4425983428955078, 0.36...     0.388373
# 22  [0.6320528984069824, 0.6510441303253174, 0.607...     0.638911
# 27  [1.1811816692352295, 1.1400108337402344, 1.158...     1.163558
# 32  [1.714876651763916, 1.6910102367401123, 1.4601...     1.649841
# 37  [35.19813132286072, 35.33528780937195, 34.5982...    35.380181
# 42  [2.2217600345611572, 2.3067665100097656, 2.341...     2.302915
# 47  [43.71550250053406, 42.31518340110779, 41.5117...    42.148502
# 52  [93.56566286087036, 92.96411442756653, 92.4680...    92.962846
# 57  [10.685043096542358, 11.175010681152344, 11.15...    10.936303
# 62  [0.11072945594787598, 0.14433956146240234, 0.1...     0.126536
# 67  [16.19028329849243, 16.325310707092285, 16.640...    16.480464
# 72  [8.216359853744507, 8.273557424545288, 8.26353...     8.236922
# 77  [1508.2326650619507, 1504.521056652069, 1510.9...  1498.612719
# 82  [4586.826099872589, 4848.72921538353, 4790.750...  4637.044397
#
# mer_jac_ws 315.792256826513
#                                     data        type  \
# 3                             main_fuzzy  mer_jac_ws
# 8                              imdb_wiki  mer_jac_ws
# 13                                 squad  mer_jac_ws
# 18               joined_abt_buy_exp_data  mer_jac_ws
# 23         joined_amazon_google_exp_data  mer_jac_ws
# 28                  joined_beer_exp_data  mer_jac_ws
# 33              joined_dblp_acm_exp_data  mer_jac_ws
# 38          joined_dblp_scholar_exp_data  mer_jac_ws
# 43        joined_dirty_dblp_acm_exp_data  mer_jac_ws
# 48    joined_dirty_dblp_scholar_exp_data  mer_jac_ws
# 53   joined_dirty_itunes_amazon_exp_data  mer_jac_ws
# 58  joined_dirty_walmart_amazon_exp_data  mer_jac_ws
# 63          joined_fodors_zagat_exp_data  mer_jac_ws
# 68         joined_itunes_amazon_exp_data  mer_jac_ws
# 73        joined_walmart_amazon_exp_data  mer_jac_ws
# 78               joined_company_exp_data  mer_jac_ws
# 83                                 marco  mer_jac_ws
#
#                                               results          avg
# 3   [5.829527854919434, 6.058440208435059, 6.31795...     6.044274
# 8   [5.300956964492798, 5.259387016296387, 5.35040...     5.576882
# 13  [1.1549208164215088, 1.1803438663482666, 1.144...     1.178234
# 18  [0.3706531524658203, 1.139054298400879, 0.3345...     0.505613
# 23  [1.0257313251495361, 0.9275681972503662, 0.981...     0.964168
# 28  [2.991100788116455, 2.945530414581299, 2.90473...     2.981624
# 33  [1.5084290504455566, 1.4217007160186768, 1.421...     1.427500
# 38  [42.13429832458496, 44.02089476585388, 43.0312...    43.407733
# 43  [1.434356451034546, 1.4491658210754395, 1.4477...     1.437472
# 48  [42.678276777267456, 41.94377565383911, 40.668...    41.645304
# 53  [108.85804986953735, 110.5441563129425, 108.78...   109.845672
# 58  [12.32909083366394, 13.035001039505005, 12.796...    12.643845
# 63  [0.13735747337341309, 0.17839717864990234, 0.1...     0.157116
# 68  [107.4761106967926, 105.1813325881958, 106.616...   106.319445
# 73  [12.474035263061523, 12.684194087982178, 12.47...    12.492657
# 78  [237.78836154937744, 239.485906124115, 240.743...   237.768996
# 83  [4803.888113260269, 4910.017649412155, 4966.68...  4784.071830
#
# mer_jac_2g 406.66994399743925
#                                     data        type  \
# 4                             main_fuzzy  mer_jac_2g
# 9                              imdb_wiki  mer_jac_2g
# 14                                 squad  mer_jac_2g
# 19               joined_abt_buy_exp_data  mer_jac_2g
# 24         joined_amazon_google_exp_data  mer_jac_2g
# 29                  joined_beer_exp_data  mer_jac_2g
# 34              joined_dblp_acm_exp_data  mer_jac_2g
# 39          joined_dblp_scholar_exp_data  mer_jac_2g
# 44        joined_dirty_dblp_acm_exp_data  mer_jac_2g
# 49    joined_dirty_dblp_scholar_exp_data  mer_jac_2g
# 54   joined_dirty_itunes_amazon_exp_data  mer_jac_2g
# 59  joined_dirty_walmart_amazon_exp_data  mer_jac_2g
# 64          joined_fodors_zagat_exp_data  mer_jac_2g
# 69         joined_itunes_amazon_exp_data  mer_jac_2g
# 74        joined_walmart_amazon_exp_data  mer_jac_2g
# 79               joined_company_exp_data  mer_jac_2g
# 84                                 marco  mer_jac_2g
#
#                                               results          avg
# 4   [12.2832670211792, 12.011268615722656, 11.8850...    12.285134
# 9   [82.20433306694031, 82.24245190620422, 81.7833...    81.811845
# 14  [8.748880624771118, 9.079378843307495, 8.88254...     8.920781
# 19  [1.255871295928955, 1.1742112636566162, 1.2728...     1.210830
# 24  [1.8947088718414307, 1.771348476409912, 1.7786...     1.839672
# 29  [6.061944246292114, 5.725556135177612, 5.74216...     5.763306
# 34  [3.4769673347473145, 3.8065288066864014, 3.633...     3.615284
# 39  [70.54696321487427, 72.20379066467285, 72.1747...    71.189787
# 44  [4.043169975280762, 3.9966213703155518, 3.6376...     3.830876
# 49  [71.14244198799133, 71.99810862541199, 70.5327...    70.915508
# 54  [212.72243428230286, 217.13317346572876, 215.1...   214.935008
# 59  [21.884234189987183, 22.64241671562195, 22.292...    22.157233
# 64  [0.3248729705810547, 0.3139505386352539, 0.329...     0.325983
# 69  [211.34194684028625, 210.78696608543396, 209.7...   211.716022
# 74  [21.743701696395874, 22.10369873046875, 21.748...    21.839512
# 79  [1555.9954409599304, 1540.2852759361267, 1551....  1543.987868
# 84  [4586.826099872589, 4848.72921538353, 4790.750...  4637.044397

# %%
mapping={'main_fuzzy': 'hard_imdb_fuzzy',
         'imdb_wiki': 'imdb_wiki',
         'squad': 'SQuAD_sent',
         'joined_abt_buy_exp_data': 'abt_buy_exp_data',
         'joined_amazon_google_exp_data': 'amazon_google_exp_data',
         'joined_beer_exp_data': 'beer_exp_data',
         'joined_dblp_acm_exp_data': 'dblp_acm_exp_data',
         'joined_dblp_scholar_exp_data': 'dblp_scholar_exp_data',
         'joined_dirty_dblp_acm_exp_data': 'dirty_dblp_acm_exp_data',
         'joined_dirty_dblp_scholar_exp_data': 'dirty_dblp_scholar_exp_data',
         'joined_dirty_itunes_amazon_exp_data': 'dirty_itunes_amazon_exp_data',
         'joined_dirty_walmart_amazon_exp_data': 'dirty_walmart_amazon_exp_data',
         'joined_fodors_zagat_exp_data': 'fodors_zagat_exp_data',
         'joined_itunes_amazon_exp_data': 'itunes_amazon_exp_data',
         'joined_walmart_amazon_exp_data': 'walmart_amazon_exp_data',
         'joined_company_exp_data': 'company_exp_data',
         'marco': 'marco'}

# %%
simjoin['model'] = simjoin.data.apply(lambda x: mapping[x])
simjoin #= simjoin[['model','avg','type']]
simjoin
# Out:
#           data        type                                            results  \
# 0   main_fuzzy    key_edit  [4.485604524612427, 2.8411519527435303, 3.4615...
# 1   main_fuzzy  key_jac_ws  [0.6551518440246582, 0.46874403953552246, 0.56...
# 2   main_fuzzy  key_jac_2g  [1.1006782054901123, 1.2680299282073975, 1.123...
# 3   main_fuzzy  mer_jac_ws  [5.829527854919434, 6.058440208435059, 6.31795...
# 4   main_fuzzy  mer_jac_2g  [12.2832670211792, 12.011268615722656, 11.8850...
# ..         ...         ...                                                ...
# 80       marco    key_edit  [4421.601225137711, 4433.547817230225, 4462.33...
# 81       marco  key_jac_ws  [4803.888113260269, 4910.017649412155, 4966.68...
# 82       marco  key_jac_2g  [4586.826099872589, 4848.72921538353, 4790.750...
# 83       marco  mer_jac_ws  [4803.888113260269, 4910.017649412155, 4966.68...
# 84       marco  mer_jac_2g  [4586.826099872589, 4848.72921538353, 4790.750...
#
#             avg            model
# 0      3.313628  hard_imdb_fuzzy
# 1      0.579899  hard_imdb_fuzzy
# 2      1.148822  hard_imdb_fuzzy
# 3      6.044274  hard_imdb_fuzzy
# 4     12.285134  hard_imdb_fuzzy
# ..          ...              ...
# 80  4452.181175            marco
# 81  4784.071830            marco
# 82  4637.044397            marco
# 83  4784.071830            marco
# 84  4637.044397            marco
#
# [85 rows x 5 columns]

# %%
list(simjoin[simjoin['type'] == 'key_jac_ws']['avg'])
# Out:
# [0.5798988819122315,
#  1.8510973453521729,
#  0.7156072139739991,
#  0.12924065589904785,
#  0.1735837459564209,
#  0.6951426982879638,
#  0.29896697998046873,
#  2.503239631652832,
#  0.4324638366699219,
#  2.2051724910736086,
#  15.299003314971923,
#  0.8243845939636231,
#  0.10497794151306153,
#  11.419182634353637,
#  0.4081582546234131,
#  301.2018307685852,
#  4784.071830368042]

# %%
np.mean([0.5798988819122315,
 1.8510973453521729,
 0.7156072139739991,
 0.12924065589904785,
 0.1735837459564209,
 0.6951426982879638,
 0.29896697998046873,
 2.503239631652832,
 0.4324638366699219,
 2.2051724910736086,
 15.299003314971923,
 0.8243845939636231,
 0.10497794151306153,
 11.419182634353637,
 0.4081582546234131,
 301.2018307685852])
# Out:
# 21.177621936798094

# %%
(36.52*17 + 4784)/17
# Out:
#     index                                  data      type  \
# 0       0                            main_fuzzy  key_edit
# 1       5                             imdb_wiki  key_edit
# 2      10                                 squad  key_edit
# 3      15               joined_abt_buy_exp_data  key_edit
# 4      20         joined_amazon_google_exp_data  key_edit
# 5      25                  joined_beer_exp_data  key_edit
# 6      30              joined_dblp_acm_exp_data  key_edit
# 7      35          joined_dblp_scholar_exp_data  key_edit
# 8      40        joined_dirty_dblp_acm_exp_data  key_edit
# 9      45    joined_dirty_dblp_scholar_exp_data  key_edit
# 10     50   joined_dirty_itunes_amazon_exp_data  key_edit
# 11     55  joined_dirty_walmart_amazon_exp_data  key_edit
# 12     60          joined_fodors_zagat_exp_data  key_edit
# 13     65         joined_itunes_amazon_exp_data  key_edit
# 14     70        joined_walmart_amazon_exp_data  key_edit
# 15     75               joined_company_exp_data  key_edit
# 16     80                                 marco  key_edit
#
#                                               results           avg  \
# 0   [4.021732568740845, 3.027381658554077, 3.17804...      3.343685
# 1   [16.26113224029541, 16.73265290260315, 16.4235...     16.477525
# 2   [5.026648044586182, 5.432934999465942, 5.21932...      5.152925
# 3   [0.5303425788879395, 0.5461370944976807, 0.552...      0.544072
# 4   [1.070925235748291, 1.051903486251831, 1.07387...      1.052562
# 5   [2.528080463409424, 2.5448250770568848, 2.4345...      2.511699
# 6   [2.142317771911621, 2.208840847015381, 2.26175...      2.210366
# 7   [46.85374474525452, 47.19393348693848, 46.5991...     46.755253
# 8   [3.0017614364624023, 2.9946720600128174, 2.993...      2.945602
# 9   [59.66959357261658, 61.01483082771301, 59.9682...     60.667127
# 10  [124.5042953491211, 126.94834804534912, 127.22...    126.375605
# 11  [23.456520557403564, 22.9233238697052, 23.4168...     23.213114
# 12  [0.23989295959472656, 0.13880085945129395, 0.1...      0.164835
# 13  [52.85706639289856, 51.19730353355408, 51.2474...     52.216603
# 14  [14.062134981155396, 14.509893655776978, 17.17...     14.994242
# 15  [20433.075062274933, 20015.029639720917, 20270...  20053.639548
# 16  [4334.607208967209, 4223.458425998688, 4464.60...   4413.127770
#
#                             model
# 0                 hard_imdb_fuzzy
# 1                       imdb_wiki
# 2                      SQuAD_sent
# 3                abt_buy_exp_data
# 4          amazon_google_exp_data
# 5                   beer_exp_data
# 6               dblp_acm_exp_data
# 7           dblp_scholar_exp_data
# 8         dirty_dblp_acm_exp_data
# 9     dirty_dblp_scholar_exp_data
# 10   dirty_itunes_amazon_exp_data
# 11  dirty_walmart_amazon_exp_data
# 12          fodors_zagat_exp_data
# 13         itunes_amazon_exp_data
# 14        walmart_amazon_exp_data
# 15               company_exp_data
# 16                          marco

# %%
simjoin[simjoin['type'] == 'key_jac_ws'].reset_index()
# Out:
#     index                                  data        type  \
# 0       1                            main_fuzzy  key_jac_ws
# 1       6                             imdb_wiki  key_jac_ws
# 2      11                                 squad  key_jac_ws
# 3      16               joined_abt_buy_exp_data  key_jac_ws
# 4      21         joined_amazon_google_exp_data  key_jac_ws
# 5      26                  joined_beer_exp_data  key_jac_ws
# 6      31              joined_dblp_acm_exp_data  key_jac_ws
# 7      36          joined_dblp_scholar_exp_data  key_jac_ws
# 8      41        joined_dirty_dblp_acm_exp_data  key_jac_ws
# 9      46    joined_dirty_dblp_scholar_exp_data  key_jac_ws
# 10     51   joined_dirty_itunes_amazon_exp_data  key_jac_ws
# 11     56  joined_dirty_walmart_amazon_exp_data  key_jac_ws
# 12     61          joined_fodors_zagat_exp_data  key_jac_ws
# 13     66         joined_itunes_amazon_exp_data  key_jac_ws
# 14     71        joined_walmart_amazon_exp_data  key_jac_ws
# 15     76               joined_company_exp_data  key_jac_ws
# 16     81                                 marco  key_jac_ws
#
#                                               results          avg  \
# 0   [0.6823546886444092, 0.5312132835388184, 0.546...     0.620494
# 1   [1.5967867374420166, 1.6109285354614258, 2.790...     1.954079
# 2   [0.6495304107666016, 0.6804955005645752, 0.697...     0.694382
# 3   [0.13864684104919434, 0.13347840309143066, 0.1...     0.131703
# 4   [0.16640639305114746, 0.1628398895263672, 0.17...     0.170303
# 5   [0.6229343414306641, 0.7665610313415527, 0.649...     0.678267
# 6   [0.2953507900238037, 0.327380895614624, 0.3057...     0.305670
# 7   [2.711008310317993, 2.5014781951904297, 2.5969...     2.710439
# 8   [0.352644681930542, 0.3225595951080322, 0.3545...     0.340504
# 9   [2.2545552253723145, 2.510944366455078, 2.3045...     2.371363
# 10  [16.606874465942383, 15.759251356124878, 16.04...    16.346275
# 11  [0.42661070823669434, 0.4174621105194092, 0.46...     0.439172
# 12  [0.11231541633605957, 0.9155709743499756, 0.11...     0.317349
# 13  [11.988362073898315, 11.91668176651001, 12.026...    12.175921
# 14  [0.3747897148132324, 0.3923068046569824, 0.418...     0.389529
# 15  [251.5351481437683, 319.0096478462219, 298.472...   302.871080
# 16  [4594.642971038818, 4486.389822721481, 4621.42...  4633.799016
#
#                             model
# 0                 hard_imdb_fuzzy
# 1                       imdb_wiki
# 2                      SQuAD_sent
# 3                abt_buy_exp_data
# 4          amazon_google_exp_data
# 5                   beer_exp_data
# 6               dblp_acm_exp_data
# 7           dblp_scholar_exp_data
# 8         dirty_dblp_acm_exp_data
# 9     dirty_dblp_scholar_exp_data
# 10   dirty_itunes_amazon_exp_data
# 11  dirty_walmart_amazon_exp_data
# 12          fodors_zagat_exp_data
# 13         itunes_amazon_exp_data
# 14        walmart_amazon_exp_data
# 15               company_exp_data
# 16                          marco
